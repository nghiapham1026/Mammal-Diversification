# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Early Cenozoic (Paleogene) Periods (Ypresian to Chattian):**
#    - The diversity of artiodactyls seems relatively low during the Ypresian and Lutetian epochs, with 6 and 19 occurrences respectively.
#    - There is a notable increase in diversity during the Bartonian and Priabonian epochs, with 30 and 35 occurrences respectively.
#    - The highest diversity within this period is observed during the Chattian epoch, with 48 occurrences.
#
# 2. **Transition from Oligocene to Miocene (Rupelian to Langhian):**
#    - The Rupelian epoch shows a decline in diversity compared to the Chattian, with 35 occurrences.
#    - However, there's a slight increase again during the Priabonian epoch (30 occurrences).
#    - The Langhian epoch shows a significant increase in diversity with 58 occurrences.
#
# 3. **Middle to Late Miocene (Serravallian to Messinian):**
#    - Diversity remains relatively high during this period, with a range of 89 to 143 occurrences across different epochs.
#
# 4. **Late Miocene to Pliocene (Tortonian to Zanclean):**
#    - The Tortonian and Messinian epochs show high diversity, with 143 and 76 occurrences respectively.
#    - The Zanclean epoch also retains relatively high diversity, with 98 occurrences.
#
# 5. **Pleistocene to Recent (Piacenzian to Late Pleistocene):**
#    - There is a noticeable decrease in diversity during the Pleistocene epochs compared to the preceding epochs, with occurrences ranging from 36 to 134.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Holocene (0 - 0.126 Myr BP):**
#    - During the Holocene, mean surface temperatures (Ts) were relatively stable at around 15°C. This stable climate likely provided favorable conditions for bird populations, resulting in high diversity.
#
# 2. **Pleistocene (0.126 - 2.588 Myr BP):**
#    - As the Pleistocene began, temperatures started to fluctuate more, with Ts ranging from approximately 12.42°C to 18.32°C.
#    - These temperature fluctuations, coupled with glacial-interglacial cycles, could have led to habitat changes and fragmentation, impacting bird populations. However, despite some variability, bird diversity remained relatively high during this period.
#
# 3. **Pliocene (2.588 - 5.333 Myr BP):**
#    - During the Pliocene, Ts ranged from around 11.35°C to 18.32°C.
#    - The gradual cooling trend during this period might have contributed to a decline in bird diversity, as some species may have struggled to adapt to changing environmental conditions.
#
# 4. **Miocene (5.333 - 23.03 Myr BP):**
#    - Throughout the Miocene, Ts gradually increased from approximately 11.35°C to 19.7°C.
#    - This period of warming could have created more favorable habitats for birds, leading to an increase in diversity, especially during intervals with higher temperatures.
#
# 5. **Oligocene and Eocene (23.03 - 56.0 Myr BP):**
#    - During the Oligocene and Eocene epochs, Ts ranged from around 17.95°C to 27.89°C.
#    - The warmer temperatures during these epochs might have supported diverse ecosystems, including various bird species adapted to different climatic conditions.
#
# 6. **Paleocene (56.0 - 66.0 Myr BP):**
#    - Ts during the Paleocene varied from approximately 22.6°C to 24.5°C.
#    - Despite the relatively stable temperatures, bird diversity might have been influenced by other factors such as habitat availability and ecological competition.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Early Cenozoic (Paleogene) Periods (Ypresian to Chattian):**
#    - Carnivore diversity appears to be minimal during these early periods, with only a few occurrences or none at all.
#
# 2. **Transition from Oligocene to Miocene (Rupelian to Langhian):**
#    - There is a slight increase in carnivore diversity during the Rupelian epoch, with 11 occurrences, and this trend continues with 30 occurrences during the Priabonian epoch.
#    - However, these numbers remain relatively low compared to other epochs.
#
# 3. **Middle to Late Miocene (Serravallian to Messinian):**
#    - The Middle to Late Miocene epochs witness a notable rise in carnivore diversity. The Tortonian epoch stands out with 217 occurrences, followed by the Serravallian epoch with 124 occurrences.
#    - This increase suggests a significant expansion in carnivore populations and ecological niches during this period.
#
# 4. **Late Miocene to Pliocene (Langhian to Zanclean):**
#    - Carnivore diversity remains relatively high during this period, with notable occurrences in the Langhian and Serravallian epochs.
#    - The Zanclean epoch also maintains a relatively high number of occurrences, indicating sustained diversity.
#
# 5. **Pleistocene to Recent (Calabrian to Late Pleistocene):**
#    - Carnivore diversity decreases during the Pleistocene epochs, with a notable decline in occurrences compared to the preceding epochs.
#    - The Late Pleistocene epoch shows a further decrease in diversity, with only 18 occurrences recorded.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Late Pleistocene (0.0117 - 0.126 Myr BP):**
#    - Cetacean diversity remains relatively low, with only 93 occurrences sampled.
#
# 2. **Middle Pleistocene (0.126 - 0.781 Myr BP):**
#    - There is a slight increase in sampled occurrences to 6, indicating a minor rise in cetacean diversity compared to the Late Pleistocene.
#
# 3. **Calabrian (0.781 - 1.806 Myr BP) and Gelasian (1.806 - 2.588 Myr BP):**
#    - Cetacean diversity continues to increase gradually, with 20 and 19 occurrences sampled, respectively.
#
# 4. **Piacenzian (2.588 - 3.6 Myr BP) to Tortonian (7.246 - 11.62 Myr BP):**
#    - There is a significant increase in cetacean diversity during this period, with sampled occurrences ranging from 41 to 130, indicating a flourishing cetacean population.
#
# 5. **Serravallian (11.62 - 13.82 Myr BP) to Burdigalian (15.97 - 20.44 Myr BP):**
#    - Cetacean diversity remains relatively high, with sampled occurrences ranging from 61 to 98, suggesting a stable population during this period.
#
# 6. **Aquitanian (20.44 - 23.03 Myr BP) to Lutetian (41.3 - 47.8 Myr BP):**
#    - Cetacean diversity decreases notably during these intervals, with sampled occurrences dropping to as low as 2, indicating a decline in cetacean populations.
#
# 7. **Ypresian (47.8 - 56.0 Myr BP) to Present:**
#    - Cetacean diversity remains extremely low, with only 2 occurrences sampled, suggesting a significant reduction in cetacean populations towards the present day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Priabonian to Bartonian (38.0 - 41.3 million years ago):**
#    - The condylarth diversity remains relatively low during this period, with only 2 to 3 occurrences sampled in each time bin.
#
# 2. **Bartonian to Lutetian (41.3 - 47.8 million years ago):**
#    - There is a slight increase in diversity during this interval, with the number of occurrences rising to 12 in the Lutetian. This suggests a moderate expansion or emergence of condylarth species during this time.
#
# 3. **Lutetian to Ypresian (47.8 - 56.0 million years ago):**
#    - The most notable increase in diversity occurs during this period, with the number of occurrences rising sharply to 27 in the Ypresian. This indicates a significant proliferation or diversification of condylarths during this epoch.
#
# 4. **Ypresian to Thanetian (56.0 - 59.2 million years ago):**
#    - The diversity remains relatively stable during this interval, with a slight increase from 27 to 36 occurrences. This suggests a continuation of the favorable conditions that supported condylarth diversity during the preceding epoch.
#
# 5. **Thanetian to Danian (59.2 - 66.0 million years ago):**
#    - The diversity remains high during the Thanetian and into the Danian, with 36 occurrences sampled in both intervals. This indicates a sustained period of stability or prosperity for condylarths leading up to the end of the Cenozoic era.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Late Paleocene to Early Eocene (Danian to Thanetian):**
#    - Creodont diversity appears to be relatively low during this period, with only a few occurrences recorded in the sampled intervals. The Thanetian interval shows a slight increase in diversity compared to the preceding Danian interval.
#
# 2. **Middle Eocene to Early Oligocene (Ypresian to Rupelian):**
#    - Creodont diversity experiences a notable increase during this period, with a significant rise in the number of occurrences recorded in each interval. The Ypresian interval marks a substantial increase in diversity, with a relatively high number of occurrences compared to previous intervals. This trend continues into the Rupelian interval, where creodont diversity remains elevated.
#
# 3. **Late Oligocene to Early Miocene (Chattian to Burdigalian):**
#    - Creodont diversity remains relatively stable during this period, with a consistent number of occurrences recorded in each interval. The Burdigalian interval stands out with a relatively high diversity compared to surrounding intervals.
#
# 4. **Middle Miocene to Late Miocene (Langhian to Tortonian):**
#    - Creodont diversity decreases during this period, with fewer occurrences recorded in each successive interval. The Tortonian interval marks a notable decline in diversity compared to previous intervals, with only one occurrence recorded.
#
# 5. **Late Miocene to Pliocene (Messinian to Maastrichtian):**
#    - Creodonts have become extinct by the late Miocene.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Increase in Diversity from Paleocene to Eocene:**
#    - Mammalian diversity starts relatively low in the Paleocene and gradually increases through the Eocene epochs.
#    - There is a notable increase in diversity from the Paleocene to the Eocene, with the highest diversity observed during the early Eocene.
#
# 2. **Peak Diversity in the Eocene:**
#    - The Eocene epoch, particularly the early and middle Eocene, exhibits the highest levels of mammalian diversity.
#    - This period is characterized by a wide range of mammalian taxa occupying various ecological niches, leading to a rich diversity of species.
#
# 3. **Decline in Diversity from Oligocene to Miocene:**
#    - Following the Eocene, there is a decline in mammalian diversity during the Oligocene and into the early Miocene epochs.
#    - The decline in diversity suggests potential environmental changes or ecological shifts that may have influenced mammalian populations during this period.
#
# 4. **Stabilization and Fluctuations in the Late Miocene to Pleistocene:**
#    - From the middle Miocene to the late Miocene and into the Pleistocene, mammalian diversity stabilizes but exhibits fluctuations.
#    - There are periods of slight increase and decrease in diversity during this time, reflecting dynamic environmental conditions and potential evolutionary events.
#
# 5. **Recent Fluctuations in the Pleistocene:**
#    - In the Late Pleistocene, there is a notable increase in diversity compared to earlier epochs, likely due to the diversification of mammalian species in response to changing climates and landscapes.
#    - The Middle Pleistocene shows a relatively lower diversity compared to the Late Pleistocene but still higher than earlier epochs, indicating continued evolutionary dynamics.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Priabonian (38.0 - 33.9 Ma):**
#    - Multituberculate diversity is low during this period, with only 1 occurrence recorded. Multituberculates became extinct at the end of the Eocene.
#
# 2. **Bartonian (41.3 - 38.0 Ma):**
#    - Multituberculates remain rare, with 1 occurrence recorded.
#
# 3. **Lutetian (47.8 - 41.3 Ma):**
#    - The diversity of multituberculates slightly increases to 1 occurrence.
#
# 4. **Ypresian (56.0 - 47.8 Ma):**
#    - There is a significant increase in multituberculate diversity during this period, with 9 occurrences recorded.
#
# 5. **Thanetian (59.2 - 56.0 Ma):**
#    - Multituberculate diversity continues to increase, reaching 21 occurrences.
#
# 6. **Selandian (61.6 - 59.2 Ma):**
#    - Multituberculate diversity remains stable with 0 occurrences recorded.
#
# 7. **Danian (66.0 - 61.6 Ma):**
#    - There is a notable surge in multituberculate diversity, with 70 occurrences recorded, indicating a significant proliferation of multituberculates during this period.
#
# 8. **Maastrichtian (72.1 - 66.0 Ma):**
#    - Multituberculate diversity remains relatively high, with 37 occurrences recorded.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Early Cenozoic (Paleocene to Eocene):**
#    - Perissodactyl diversity appears to have been relatively low during the early Cenozoic epochs, including the Ypresian, Thanetian, Lutetian, Bartonian, and Priabonian intervals. The number of sampled occurrences (sampled_in_bin) is generally modest during this period, with some fluctuations.
#
# 2. **Middle Cenozoic (Oligocene to Miocene):**
#    - The trend shows an increase in perissodactyl diversity during the Oligocene and Miocene epochs. There is a notable rise in diversity starting from the Chattian through the Aquitanian intervals, with significant numbers of occurrences recorded in the Tortonian, Serravallian, and Langhian intervals. This period represents a peak in perissodactyl diversity during the Cenozoic.
#
# 3. **Late Cenozoic (Pliocene to Pleistocene):**
#    - Perissodactyl diversity remains relatively high during the late Cenozoic epochs, particularly in the Zanclean through to the Late Pleistocene intervals. The number of occurrences remains substantial, indicating that perissodactyls were still relatively diverse and widespread during this time.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Lutetian (47.8 - 41.3 million years ago):**
#    - During the Lutetian epoch, there is minimal recorded diversity of plesiadapiformes, with only one occurrence sampled in the bin.
#
# 2. **Ypresian (56.0 - 47.8 million years ago):**
#    - Plesiadapiformes diversity slightly increases during the Ypresian epoch, with five occurrences sampled in the bin, indicating a small but detectable presence of these mammals.
#
# 3. **Thanetian (59.2 - 56.0 million years ago):**
#    - Similar to the Lutetian epoch, there is minimal diversity of plesiadapiformes during the Thanetian, with only one occurrence sampled in the bin.
#
# 4. **Selandian (61.6 - 59.2 million years ago):**
#    - No occurrences of plesiadapiformes are recorded during the Selandian epoch, indicating a potential absence or very low diversity of these mammals during this time period.
#
# 5. **Danian (66.0 - 61.6 million years ago):**
#    - Plesiadapiformes diversity increases notably during the Danian epoch, with 19 occurrences sampled in the bin, suggesting a significant presence of these mammals during this period.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Late Pleistocene (0.126 - 0.0117 million years ago):**
#    - Primate diversity is relatively high during the Late Pleistocene, with 48 occurrences sampled in the bin. This period represents a time of significant diversification and adaptation of primates to various environments.
#
# 2. **Middle Pleistocene (0.781 - 0.126 million years ago):**
#    - Primate diversity remains moderately high during the Middle Pleistocene, with 30 occurrences sampled in the bin. This epoch continues to witness the presence of various primate species, although the diversity might slightly decrease compared to the Late Pleistocene.
#
# 3. **Calabrian (1.806 - 0.781 million years ago):**
#    - Primate diversity remains relatively high during the Calabrian epoch, with 61 occurrences sampled in the bin. This period reflects a stable diversity of primates, indicating their adaptability and persistence in diverse environments.
#
# 4. **Gelasian (2.588 - 1.806 million years ago):**
#    - Primate diversity decreases slightly during the Gelasian epoch, with 15 occurrences sampled in the bin. This period might witness some environmental changes leading to a slight decline in primate diversity.
#
# 5. **Piacenzian (3.6 - 2.588 million years ago):**
#    - Primate diversity experiences a slight increase during the Piacenzian epoch, with 25 occurrences sampled in the bin. This period marks a rebound in primate diversity following the decline observed in the previous epoch.
#
# 6. **Zanclean (5.333 - 3.6 million years ago):**
#    - Primate diversity remains relatively stable during the Zanclean epoch, with 32 occurrences sampled in the bin. This period represents a continuation of the diverse primate fauna established in earlier epochs.
#
# 7. **Messinian (7.246 - 5.333 million years ago):**
#    - Primate diversity remains stable during the Messinian epoch, with 21 occurrences sampled in the bin. This period might witness some environmental changes, but overall, the diversity of primates remains consistent.
#
# 8. **Tortonian (11.62 - 7.246 million years ago):**
#    - Primate diversity experiences a significant increase during the Tortonian epoch, with 127 occurrences sampled in the bin. This period marks a notable expansion and diversification of primate species.
#
# 9. **Serravallian (13.82 - 11.62 million years ago):**
#    - Primate diversity remains high during the Serravallian epoch, with 85 occurrences sampled in the bin. This period continues to witness a diverse array of primate species.
#
# 10. **Langhian (15.97 - 13.82 million years ago):**
#    - Primate diversity remains relatively stable during the Langhian epoch, with 76 occurrences sampled in the bin. This period represents a continuation of the diverse primate fauna established in earlier epochs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Late Pleistocene and Middle Pleistocene:**
#    - Proboscidea diversity appears to be relatively low during these periods, with only a few occurrences recorded.
#
# 2. **Calabrian to Messinian (1.806 Ma to 7.246 Ma):**
#    - During the Calabrian and Gelasian epochs, there is a slight increase in proboscidea diversity compared to earlier periods, with a small number of occurrences recorded.
#    - Proboscidea diversity remains relatively low during the Piacenzian and Zanclean epochs, with only a few occurrences documented.
#    - However, during the Messinian epoch, there is a notable increase in diversity, with a significant number of occurrences recorded.
#
# 3. **Tortonian to Chattian (11.62 Ma to 28.1 Ma):**
#    - Proboscidea diversity remains relatively low during the Tortonian and Serravallian epochs, with only a few occurrences documented.
#    - A slight increase in diversity is observed during the Langhian epoch, although the number of occurrences remains limited.
#    - The Burdigalian epoch marks a significant increase in proboscidea diversity, with a substantial number of occurrences recorded.
#    - Proboscidea diversity remains relatively high during the Aquitanian and Chattian epochs, with a significant number of occurrences documented.
#
# 4. **Rupelian to Ypresian (33.9 Ma to 56.0 Ma):**
#    - Proboscidea diversity fluctuates during the Rupelian epoch, with a moderate number of occurrences recorded.
#    - A notable increase in diversity is observed during the Priabonian epoch, with a large number of occurrences documented.
#    - Proboscidea diversity remains relatively low during the Bartonian and Lutetian epochs, with only a few occurrences recorded.
#    - A slight increase in diversity is observed during the Ypresian epoch, although the number of occurrences remains limited.
#
# 5. **Thanetian to Maastrichtian (59.2 Ma to 72.1 Ma):**
#    - Proboscidea diversity is relatively low during the Thanetian epoch, with only a few occurrences recorded.
#    - Similarly, diversity remains low during the Selandian and Danian epochs, with only a small number of occurrences documented.
#    - Proboscidea diversity appears to be minimal during the Maastrichtian epoch, with very few occurrences recorded.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **High Diversity in the Late Cretaceous (Maastrichtian Stage):**
#    - The Late Cretaceous period, specifically the Maastrichtian stage, exhibits the highest diversity of non-avian reptiles, with 550 occurrences sampled in the bin.
#    - This high diversity is evident from the significant number of occurrences (6879) implied in the bin, indicating a rich reptilian fauna during this time.
#
# 2. **Decline in Diversity Post-Cretaceous:**
#    - Following the Maastrichtian stage, there is a noticeable decline in non-avian reptile diversity as we enter the Paleogene and Neogene periods of the Cenozoic era.
#    - While there are still occurrences of non-avian reptiles throughout the Cenozoic, the numbers sampled in the bin gradually decrease, indicating a diminishing diversity over time.
#
# 3. **Fluctuations in Diversity during the Neogene:**
#    - Within the Neogene period, there are fluctuations in non-avian reptile diversity, with some intervals showing slight increases followed by decreases.
#    - For instance, there is a peak in diversity during the Tortonian stage, with 195 occurrences sampled in the bin, suggesting a temporary resurgence in reptile diversity during this time.
#    - However, these fluctuations are not sustained, and overall diversity continues to decline as we progress through the Neogene.
#
# 4. **Low Diversity in the Quaternary:**
#    - By the Late Pleistocene, non-avian reptile diversity is significantly reduced, with only 225 occurrences sampled in the bin.
#    - This low diversity persists into the Middle Pleistocene and Late Pleistocene epochs, indicating a general trend of decline in non-avian reptile diversity leading up to the present day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Increase in Diversity from the Eocene to the Oligocene:**
#    - Rodent diversity shows a notable increase from the Eocene to the Oligocene epochs.
#    - The rise in diversity is particularly evident from the Aquitanian to the Chattian stages, with a significant increase in sampled occurrences and implied occurrences in the bin.
#    - This period marks a transition from relatively low diversity in the Eocene to higher diversity levels by the Oligocene.
#
# 2. **Fluctuations in Diversity during the Miocene and Pliocene:**
#    - Throughout the Miocene and Pliocene epochs, rodent diversity exhibits fluctuations.
#    - There are intervals, such as the Langhian and Burdigalian stages, characterized by relatively high diversity levels.
#    - Conversely, there are intervals like the Priabonian and Bartonian stages where diversity levels are comparatively lower.
#
# 3. **Peak Diversity in the Late Miocene (Messinian and Tortonian):**
#    - The Late Miocene, specifically the Messinian and Tortonian stages, represents a peak in rodent diversity.
#    - During this period, there is a substantial increase in sampled occurrences and implied occurrences in the bin, indicating a rich rodent fauna.
#
# 4. **Decline in Diversity from the Pliocene to the Pleistocene:**
#    - Rodent diversity shows a declining trend from the Late Miocene into the Pleistocene.
#    - While there are still occurrences of rodents during the Pleistocene, the number of sampled occurrences and implied occurrences in the bin decreases, reflecting a decrease in overall diversity.
#
# 5. **Low Diversity in the Late Pleistocene:**
#    - By the Late Pleistocene, rodent diversity is relatively low compared to earlier epochs.
#    - The number of sampled occurrences and implied occurrences in the bin decreases significantly during this period, indicating a decline in rodent diversity leading up to the present day.

# %% [markdown]
# ![image.png](attachment:image.png)
